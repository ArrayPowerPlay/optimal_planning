# %%
def chia_so(a, b):
    ket_qua = a / b
    return ket_qua

chia_so(10, 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 def chia_so(a, b):
#       2     ket_qua = a / b
#       3     return ket_qua
#       4
# ----> 5 chia_so(10, 0)
#
# Cell In[3], line 2, in chia_so(a, b)
#       1 def chia_so(a, b):
# ----> 2     ket_qua = a / b
#       3     return ket_qua
#
# ZeroDivisionError: division by zero

# %%
# %debug
# Out:
# > d:\temp\ipykernel_12888\2268275165.py(2)chia_so()
# ipdb>  p a
# 10
# ipdb>  p b
# 0
# ipdb>  u
# > d:\temp\ipykernel_12888\2268275165.py(5)<module>()
# ipdb>  d
# > d:\temp\ipykernel_12888\2268275165.py(2)chia_so()
# ipdb>  w
#     [... skipping 1 hidden frame(s)]
#   d:\temp\ipykernel_12888\2268275165.py(5)<module>()
# > d:\temp\ipykernel_12888\2268275165.py(2)chia_so()
# ipdb>  h
# Documented commands (type help <topic>):
# ...
# EOF        cont        help           p        return           undisplay
# a          context     ignore         pdef     retval           unignore_module
# alias      continue    ignore_module  pdoc     run              unt
# args       d           interact       pfile    rv               until
# b          debug       j              pinfo    s                up
# break      disable     jump           pinfo2   skip_hidden      w
# bt         display     l              pp       skip_predicates  whatis
# ...
